# %% [markdown]
# This script generates a database of the full ringdown catalogue from GWTC-1 through GWTC-3, storing the strain hdf5 files by interferometer and separating them by duration (32 and 4096 seconds). It also stores the posterior samples for each event, formatted by ringdb.

# %% [markdown]
# ## TODO - CHECK IF DIRECTORIES/FILES ALREADY EXIST BEFORE GENERATING DATABASE. <br>
# ## CHANGE db_dir INPUT TO ARGPARSE

# %%
import subprocess
from ringdb import Database

# %%
db_dir = "./Database" #db_dir will be made into a string corresponding to where you want to place the database
#with open("database_path.txt","r") as file:
#    db_dir = file.read()
#if db_dir == "":
#    raise ValueError("db_dir not set to any path")

# %%
db = Database(db_dir)#instantiate database object that will create directory structure
db.initialize()
# Out:
# Creating a folder at ./Database/PosteriorData
# Creating a folder at ./Database/StrainData

# %%
df_strain = db.StrainDB.url_df #make dataframe of strain urls

# %%
subprocess.run(["mkdir",(db_dir+"/StrainData/32_s")]) # make directory for 32_s strains
subprocess.run(["mkdir",(db_dir+"/StrainData/4096_s")]) # make directory for 4096_s strains
# Out:
# CompletedProcess(args=['mkdir', './Database/StrainData/4096_s'], returncode=0)

# %%
print("Getting all available 32 second duration strain data")
for h in df_strain[df_strain["Duration"]==32.0]["Url"].values:
    print(h)
    subprocess.run(["wget",h],cwd=(db_dir+"/StrainData/32_s"))
print("Getting all available 4096 second duration strain data")
for h in df_strain[df_strain["Duration"]==4096.0]["Url"].values:
    print(h)
    subprocess.run(["wget",h],cwd=(db_dir+"/StrainData/4096_s"))
# Out:
# Getting all available 32 second duration strain data
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151012/v3/H-H1_GWOSC_16KHZ_R1-1128678885-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151012/v3/L-L1_GWOSC_16KHZ_R1-1128678885-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151226/v2/H-H1_GWOSC_16KHZ_R1-1135136335-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151226/v2/L-L1_GWOSC_16KHZ_R1-1135136335-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170104/v2/H-H1_GWOSC_16KHZ_R1-1167559921-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170104/v2/L-L1_GWOSC_16KHZ_R1-1167559921-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170608/v3/H-H1_GWOSC_16KHZ_R1-1180922479-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170608/v3/L-L1_GWOSC_16KHZ_R1-1180922479-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170729/v1/H-H1_GWOSC_16KHZ_R1-1185389792-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170729/v1/L-L1_GWOSC_16KHZ_R1-1185389792-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170729/v1/V-V1_GWOSC_16KHZ_R1-1185389792-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170809/v1/H-H1_GWOSC_16KHZ_R1-1186302504-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170809/v1/L-L1_GWOSC_16KHZ_R1-1186302504-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170809/v1/V-V1_GWOSC_16KHZ_R1-1186302504-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170814/v3/H-H1_GWOSC_16KHZ_R1-1186741846-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170814/v3/L-L1_GWOSC_16KHZ_R1-1186741846-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170814/v3/V-V1_GWOSC_16KHZ_R1-1186741846-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170817/v3/H-H1_GWOSC_16KHZ_R1-1187008867-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170817/v3/L-L1_GWOSC_16KHZ_R1-1187008867-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170817/v3/V-V1_GWOSC_16KHZ_R1-1187008867-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170818/v1/H-H1_GWOSC_16KHZ_R1-1187058312-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170818/v1/L-L1_GWOSC_16KHZ_R1-1187058312-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170818/v1/V-V1_GWOSC_16KHZ_R1-1187058312-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170823/v1/H-H1_GWOSC_16KHZ_R1-1187529241-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW
32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200216_220804/v1/V-V1_GWOSC_16KHZ_R1-1265926087-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200219_094415/v1/H-H1_GWOSC_16KHZ_R1-1266140658-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200219_094415/v1/L-L1_GWOSC_16KHZ_R1-1266140658-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200219_094415/v1/V-V1_GWOSC_16KHZ_R1-1266140658-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200220_061928/v1/H-H1_GWOSC_16KHZ_R1-1266214771-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200220_061928/v1/L-L1_GWOSC_16KHZ_R1-1266214771-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200220_061928/v1/V-V1_GWOSC_16KHZ_R1-1266214771-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200220_124850/v1/H-H1_GWOSC_16KHZ_R1-1266238133-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200220_124850/v1/L-L1_GWOSC_16KHZ_R1-1266238133-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200224_222234/v1/H-H1_GWOSC_16KHZ_R1-1266618157-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200224_222234/v1/L-L1_GWOSC_16KHZ_R1-1266618157-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200224_222234/v1/V-V1_GWOSC_16KHZ_R1-1266618157-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200225_060421/v1/H-H1_GWOSC_16KHZ_R1-1266645864-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200225_060421/v1/L-L1_GWOSC_16KHZ_R1-1266645864-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200302_015811/v1/H-H1_GWOSC_16KHZ_R1-1267149494-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200302_015811/v1/V-V1_GWOSC_16KHZ_R1-1267149494-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200306_093714/v1/H-H1_GWOSC_16KHZ_R1-1267522637-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200306_093714/v1/L-L1_GWOSC_16KHZ_R1-1267522637-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200308_173609/v1/H-H1_GWOSC_16KHZ_R1-1267724172-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200308_173609/v1/L-L1_GWOSC_16KHZ_R1-1267724172-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200308_173609/v1/V-V1_GWOSC_16KHZ_R1-1267724172-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200311_115853/v1/H-H1_GWOSC_16KHZ_R1-1267963136-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200311_115853/v1/L-L1_GWOSC_16KHZ_R1-1267963136-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200311_115853/v1/V-V1_GWOSC_16KHZ_R1-1267963136-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200316_215756/v1/H-H1_GWOSC_16KHZ_R1-1268431079-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200316_215756/v1/L-L1_GWOSC_16KHZ_R1-1268431079-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200316_215756/v1/V-V1_GWOSC_16KHZ_R1-1268431079-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200322_091133/v1/H-H1_GWOSC_16KHZ_R1-1268903496-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200322_091133/v1/L-L1_GWOSC_16KHZ_R1-1268903496-32.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200322_091133/v1/V-V1_GWOSC_16KHZ_R1-1268903496-32.hdf5
# Getting all available 4096 second duration strain data
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151012/v3/H-H1_GWOSC_16KHZ_R1-1128676853-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151012/v3/L-L1_GWOSC_16KHZ_R1-1128676853-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151226/v2/H-H1_GWOSC_16KHZ_R1-1135134303-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151226/v2/L-L1_GWOSC_16KHZ_R1-1135134303-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170104/v2/H-H1_GWOSC_16KHZ_R1-1167557889-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170104/v2/L-L1_GWOSC_16KHZ_R1-1167557889-4096.hdf5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-48280a9a6c72> in <module>
#       6 for h in df_strain[df_strain["Duration"]==4096.0]["Url"].values:
#       7     print(h)
# ----> 8     subprocess.run(["wget",h],cwd=(db_dir+"/StrainData/4096_s"))
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493     with Popen(*popenargs, **kwargs) as process:
#     494         try:
# --> 495             stdout, stderr = process.communicate(input, timeout=timeout)
#     496         except TimeoutExpired as exc:
#     497             process.kill()
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1018                 stderr = self.stderr.read()
#    1019                 self.stderr.close()
# -> 1020             self.wait()
#    1021         else:
#    1022             if timeout is not None:
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1806                         if self.returncode is not None:
#    1807                             break  # Another thread waited.
# -> 1808                         (pid, sts) = self._try_wait(0)
#    1809                         # Check the pid and loop as waitpid has been known to
#    1810                         # return 0 even without WNOHANG in odd situations.
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1764             """All callers to this function MUST hold self._waitpid_lock."""
#    1765             try:
# -> 1766                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1767             except ChildProcessError:
#    1768                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
for h in df_strain[df_strain["Duration"]==4096.0]["Url"].values:
    print(h)
    subprocess.run(["wget",h],cwd=(db_dir+"/StrainData/4096_s"))
# Out:
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151012/v3/H-H1_GWOSC_16KHZ_R1-1128676853-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151012/v3/L-L1_GWOSC_16KHZ_R1-1128676853-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151226/v2/H-H1_GWOSC_16KHZ_R1-1135134303-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW151226/v2/L-L1_GWOSC_16KHZ_R1-1135134303-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170104/v2/H-H1_GWOSC_16KHZ_R1-1167557889-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170104/v2/L-L1_GWOSC_16KHZ_R1-1167557889-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170608/v3/H-H1_GWOSC_16KHZ_R1-1180920447-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170608/v3/L-L1_GWOSC_16KHZ_R1-1180920447-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170729/v1/H-H1_GWOSC_16KHZ_R1-1185387760-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170729/v1/L-L1_GWOSC_16KHZ_R1-1185387760-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170729/v1/V-V1_GWOSC_16KHZ_R1-1185387760-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170809/v1/H-H1_GWOSC_16KHZ_R1-1186300472-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170809/v1/L-L1_GWOSC_16KHZ_R1-1186300472-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170809/v1/V-V1_GWOSC_16KHZ_R1-1186300472-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170814/v3/H-H1_GWOSC_16KHZ_R1-1186739814-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170814/v3/L-L1_GWOSC_16KHZ_R1-1186739814-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170814/v3/V-V1_GWOSC_16KHZ_R1-1186739814-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170817/v3/H-H1_GWOSC_16KHZ_R1-1187006835-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170817/v3/L-L1_GWOSC_16KHZ_R1-1187006835-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170817/v3/V-V1_GWOSC_16KHZ_R1-1187006835-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170818/v1/H-H1_GWOSC_16KHZ_R1-1187056280-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170818/v1/L-L1_GWOSC_16KHZ_R1-1187056280-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170818/v1/V-V1_GWOSC_16KHZ_R1-1187056280-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170823/v1/H-H1_GWOSC_16KHZ_R1-1187527209-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170823/v1/L-L1_GWOSC_16KHZ_R1-1187527209-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW190403_051519/v1/H-H1_GWOSC_16KHZ_R1-1238301690-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW190403_051519/v1/L-L1_GWOSC_16KHZ_R1-1238301690-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW190408_181802/v2/H-H1_GWOSC_16KHZ_R1-1238780653-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW190408_181802/v2/L-L1_GWOSC_16KHZ_R1-1238780653-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW190408_181802/v2/V-V1_GWOSC_16KHZ_R1-1238780653-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW190412/v4/H-H1_GWOSC_16KHZ_R1-1239080215-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW190412/v4/L-L1_GWOSC_16KHZ_R1-1239080215-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW190412/v4/V-V1_GWOSC_16KHZ_R1-1239080215-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW190413_052954/v2/H-H1_GWOSC_16KHZ_R1-1239166565-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW190413_052954/v2/L-L1_GWOSC_16KHZ_R1-1239166565-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-2.1-confident/GW
4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200224_222234/v1/V-V1_GWOSC_16KHZ_R1-1266616125-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200225_060421/v1/H-H1_GWOSC_16KHZ_R1-1266643832-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200225_060421/v1/L-L1_GWOSC_16KHZ_R1-1266643832-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200302_015811/v1/H-H1_GWOSC_16KHZ_R1-1267147462-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200302_015811/v1/V-V1_GWOSC_16KHZ_R1-1267147462-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200306_093714/v1/H-H1_GWOSC_16KHZ_R1-1267520605-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200306_093714/v1/L-L1_GWOSC_16KHZ_R1-1267520605-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200308_173609/v1/H-H1_GWOSC_16KHZ_R1-1267722140-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200308_173609/v1/L-L1_GWOSC_16KHZ_R1-1267722140-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200308_173609/v1/V-V1_GWOSC_16KHZ_R1-1267722140-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200311_115853/v1/H-H1_GWOSC_16KHZ_R1-1267961104-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200311_115853/v1/L-L1_GWOSC_16KHZ_R1-1267961104-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200311_115853/v1/V-V1_GWOSC_16KHZ_R1-1267961104-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200316_215756/v1/H-H1_GWOSC_16KHZ_R1-1268429047-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200316_215756/v1/L-L1_GWOSC_16KHZ_R1-1268429047-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200316_215756/v1/V-V1_GWOSC_16KHZ_R1-1268429047-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200322_091133/v1/H-H1_GWOSC_16KHZ_R1-1268901464-4096.hdf5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-cf831affb83c> in <module>
#       1 for h in df_strain[df_strain["Duration"]==4096.0]["Url"].values:
#       2     print(h)
# ----> 3     subprocess.run(["wget",h],cwd=(db_dir+"/StrainData/4096_s"))
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493     with Popen(*popenargs, **kwargs) as process:
#     494         try:
# --> 495             stdout, stderr = process.communicate(input, timeout=timeout)
#     496         except TimeoutExpired as exc:
#     497             process.kill()
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1018                 stderr = self.stderr.read()
#    1019                 self.stderr.close()
# -> 1020             self.wait()
#    1021         else:
#    1022             if timeout is not None:
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1806                         if self.returncode is not None:
#    1807                             break  # Another thread waited.
# -> 1808                         (pid, sts) = self._try_wait(0)
#    1809                         # Check the pid and loop as waitpid has been known to
#    1810                         # return 0 even without WNOHANG in odd situations.
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1764             """All callers to this function MUST hold self._waitpid_lock."""
#    1765             try:
# -> 1766                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1767             except ChildProcessError:
#    1768                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
for h in df_strain[df_strain["Duration"]==4096.0]["Url"].values[-3::]:
    print(h)
    subprocess.run(["wget",h],cwd=(db_dir+"/StrainData/4096_s"))
# Out:
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200322_091133/v1/H-H1_GWOSC_16KHZ_R1-1268901464-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200322_091133/v1/L-L1_GWOSC_16KHZ_R1-1268901464-4096.hdf5
# https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200322_091133/v1/V-V1_GWOSC_16KHZ_R1-1268901464-4096.hdf5

# %%
for eventname in db.event_list(): # get the posteriors and psds for each event
        evt = db.event(eventname)
        evt.psd()
        evt.posteriors()
# Out:
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW150914_PSDs.dat
# Samples from GWTC-1 come in one file, and there isn't a straightforward
# a way to download only one particular event from GWTC-1.
# So we have to download them together
# Downloading file from https://dcc.ligo.org/public/0168/P2000193/002/pesummary_samples.zip
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW151012_PSDs.dat
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW151226_PSDs.dat
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW170104_PSDs.dat
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW170608_PSDs.dat
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW170729_PSDs.dat
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW170809_PSDs.dat
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW170814_PSDs.dat
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW170817_PSDs.dat
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW170818_PSDs.dat
# Downloading file from https://dcc.ligo.org/public/0158/P1900011/001/GWTC1_GW170823_PSDs.dat
# Downloading file from https://zenodo.org/record/5117703/files/IGWN-GWTC2p1-v1-GW190403_051519_PEDataRelease.h5?download=1
# Downloading file from https://dcc.ligo.org/public/0169/P2000223/007/GW190408_181802.tar
# Downloading file from https://dcc.ligo.org/public/0169/P2000223/007/GW190412.tar
# Downloading file from https://dcc.ligo.org/public/0169/P2000223/007/GW190413_052954.tar
# Downloading file from https://dcc.ligo.org/public/0169/P2000223/007/GW190413_134308.tar
# Downloading file from https://dcc.ligo.org/public/0169/P2000223/007/GW190421_213856.tar
# Downloading file from https://dcc.ligo.org/public/0169/P2000223/007/GW190425.tar
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-a3dfc749d5ee> in <module>
#       2         evt = db.event(eventname)
#       3         evt.psd()
# ----> 4         evt.posteriors()
#
# ~/Documents/RelativityResearch/ringdownnew2/playarea/analysis/packages/ringdb/ringdb/Database.py in posteriors(self, **kwargs)
#     100             being a posterior sample and the columns the parameter
#     101         """
# --> 102         return self.PD_ref.posteriors(self.name, **kwargs)
#     103
#     104     def psd(self, detector=None):
#
# ~/Documents/RelativityResearch/ringdownnew2/playarea/analysis/packages/ringdb/ringdb/PosteriorDatabase.py in posteriors(self, eventname, peaks, f_ref, f_low)
#     223                 df_posteriors_all['waveform_code'] = int(waveform_code)
#     224                 if f"/{approx}/meta_data/meta_data" in f:
# --> 225                     f_ref = f[f"/{approx}/meta_data/meta_data/f_ref"][()]
#     226                     f_low = f[f"/{approx}/meta_data/meta_data/f_low"][()]
#     227         elif (file_type == 'dat'):
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/h5py/_hl/group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# KeyError: "Unable to open object (object 'f_ref' doesn't exist)"
